# %% [markdown]
# # Лінійна регресія: перенавчання і регуляризація

# %% [markdown]
# У цьому завданні ми на прикладах побачимо, як перенавчаються лінійні моделі, розберемо, чому так відбувається, і з'ясуємо, як діагностувати та контролювати перенавчання.
#
# В усіх комірках, де вказаний коментар з інструкціями, потрібно написати код, який виконує ці інструкції. Решту комірок із кодом (без коментарів) треба просто виконати. Крім того, у завданні необхідно відповідати на запитання; відповіді потрібно вписувати після виділеного слова "__Відповідь:__".

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Ми будемо працювати з датасетом __"bikes_rent.csv"__, у якому по днях записані календарна інформація та погодні умови, що характеризують автоматизовані пункти прокату велосипедів, а також кількість прокатів у цей день. Останнє ми будемо передбачати; таким чином, ми будемо розв'язувати завдання регресії.

# %% [markdown]
# ### Ознайомлення з даними

# %% [markdown]
# ## Завдання 1

# %% [markdown]
# Завантажте датасет за допомогою функції __pandas.read_csv__ у змінну __df__. Виведіть перші 5 рядків, щоб переконатися в коректному зчитуванні даних:

# %%
# Load data from file 
url = "/Users/olgatsyban/Downloads/bikes_rent.csv"
df = pd.read_csv(url)
print(df.head())
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
#
#       atemp      hum  windspeed(mph)  windspeed(ms)   cnt
# 0  18.18125  80.5833       10.749882       4.805490   985
# 1  17.68695  69.6087       16.652113       7.443949   801
# 2   9.47025  43.7273       16.636703       7.437060  1349
# 3  10.60610  59.0435       10.739832       4.800998  1562
# 4  11.46350  43.6957       12.522300       5.597810  1600

# %% [markdown]
# Для кожного дня прокату відомі такі ознаки:
# * _season_: 1 — весна, 2 — літо, 3 — осінь, 4 — зима
# * _yr_: 0 — 2011, 1 — 2012
# * _mnth_: від 1 до 12
# * _holiday_: 0 — немає свята, 1 — є свято
# * _weekday_: від 0 до 6
# * _workingday_: 0 — неробочий день, 1 — робочий день
# * _weathersit_: оцінка сприятливості погоди від 1 (чистий, ясний день) до 4 (злива, туман)
# * _temp_: температура в Цельсіях
# * _atemp_: температура за відчуттями в Цельсіях
# * _hum_: вологість
# * _windspeed(mph)_: швидкість вітру в милях за годину
# * _windspeed(ms)_: швидкість вітру в метрах за секунду
# * _cnt_: кількість орендованих велосипедів (це цільова ознака, її ми будемо передбачати)
#
# Отже, у нас є речові, бінарні та номінальні (порядкові) ознаки, і з усіма з них можна працювати як з речовими. З номінальними ознаками теж можна працювати як з речовими, тому що на них заданий порядок. Давайте подивимося на графіках, як цільова ознака залежить від решти.

# %% [markdown]
# Побудуйте графіки залежностей атрибутів від кількості поїздок. Іншими словами, вам потрібно побудувати 12 графіків. На кожному має бути зображена залежність чергового атрибута від змінної **cnt**.

# %%
# build diagrams dependence of attributes on cnt

attributes = ['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday', 
              'weathersit', 'temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)']

num_cols = 3
num_rows = len(attributes) // num_cols + (1 if len(attributes) % num_cols != 0 else 0)

fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, 15))

for i, attribute in enumerate(attributes):
    row = i // num_cols
    col = i % num_cols
    axs[row, col].bar(df[attribute], df['cnt'], alpha=0.5)
    axs[row, col].set_title('Dependence of cnt on {}'.format(attribute))
    axs[row, col].set_xlabel(attribute)
    axs[row, col].set_ylabel('Count of trips')
    axs[row, col].grid(True)

# Hide empty subplots
for i in range(len(attributes), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    axs[row, col].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# __Запитання:__
# 1. Яким є характер залежності кількості прокатів від місяця?
# >Відповідь: Залежність буде мати сезонний характер, оскільки погода та інші фактори можуть впливати на популярність прокату велосипедів у різні місяці року. На нашому графіку помітно , що кількість орендованих велосипедів збільшується у теплі пори року (весна, літо та перші місяці осені). Також варто зазначити,що кількість свят має вплив на оренду, якщо є свято, то кількість орендованих велосипедів менша.
#
# 1. Вкажіть одну або дві ознаки, від яких кількість прокатів скоріше за все залежить лінійно.
# >Відповідь: кількість прокатів від вітру (швидкість вітру - windspeed) та погоди (weathersit) може залежати лінійно.

# %% [markdown]
# ## Завдання 2
#
# Давайте більш строго оцінимо рівень лінійної залежності між ознаками та цільовою змінною. Гарною мірою лінійної залежності між двома векторами є кореляція Пірсона. Нам уже доводилося мати з нею справу раніше. Для її обчислення в pandas можна використовувати методи датафрейму: corr і corrwith.

# %% [markdown]
# Порахуйте кореляції всіх ознак, окрім останньої, з останньою за допомогою методу `corrwith`.

# %%
# find the correlation
df[attributes].corr()
# Out:
#                   season        yr      mnth   holiday   weekday  workingday  \
# season          1.000000 -0.001844  0.831440 -0.010537 -0.003080    0.012485
# yr             -0.001844  1.000000 -0.001792  0.007954 -0.005461   -0.002013
# mnth            0.831440 -0.001792  1.000000  0.019191  0.009509   -0.005901
# holiday        -0.010537  0.007954  0.019191  1.000000 -0.101960   -0.253023
# weekday        -0.003080 -0.005461  0.009509 -0.101960  1.000000    0.035790
# workingday      0.012485 -0.002013 -0.005901 -0.253023  0.035790    1.000000
# weathersit      0.019211 -0.048727  0.043528 -0.034627  0.031087    0.061200
# temp            0.334315  0.047604  0.220205 -0.028556 -0.000170    0.052660
# atemp           0.342876  0.046106  0.227459 -0.032507 -0.007537    0.052182
# hum             0.205445 -0.110651  0.222204 -0.015937 -0.052232    0.024327
# windspeed(mph) -0.229046 -0.011817 -0.207502  0.006292  0.014282   -0.018796
# windspeed(ms)  -0.229046 -0.011817 -0.207502  0.006292  0.014282   -0.018796
#
#                 weathersit      temp     atemp       hum  windspeed(mph)  \
# season            0.019211  0.334315  0.342876  0.205445       -0.229046
# yr               -0.048727  0.047604  0.046106 -0.110651       -0.011817
# mnth              0.043528  0.220205  0.227459  0.222204       -0.207502
# holiday          -0.034627 -0.028556 -0.032507 -0.015937        0.006292
# weekday           0.031087 -0.000170 -0.007537 -0.052232        0.014282
# workingday        0.061200  0.052660  0.052182  0.024327       -0.018796
# weathersit        1.000000 -0.120602 -0.121583  0.591045        0.039511
# temp             -0.120602  1.000000  0.991702  0.126963       -0.157944
# atemp            -0.121583  0.991702  1.000000  0.139988       -0.183643
# hum               0.591045  0.126963  0.139988  1.000000       -0.248489
# windspeed(mph)    0.039511 -0.157944 -0.183643 -0.248489        1.000000
# windspeed(ms)     0.039511 -0.157944 -0.183643 -0.248489        1.000000
#
#                 windspeed(ms)
# season              -0.229046
# yr                  -0.011817
# mnth                -0.207502
# holiday              0.006292
# weekday              0.014282
# workingday          -0.018796
# weathersit           0.039511
# temp                -0.157944
# atemp               -0.183643
# hum                 -0.248489
# windspeed(mph)       1.000000
# windspeed(ms)        1.000000

# %%
# find the correlation with the last attribute <cnt>
df[attributes].corrwith(df['cnt'])
# Out:
# season            0.406100
# yr                0.566710
# mnth              0.279977
# holiday          -0.068348
# weekday           0.067443
# workingday        0.061156
# weathersit       -0.297391
# temp              0.627494
# atemp             0.631066
# hum              -0.100659
# windspeed(mph)   -0.234545
# windspeed(ms)    -0.234545
# dtype: float64

# %% [markdown]
# У вибірці є ознаки, що корелюють із цільовою, а отже, завдання можна розв'язувати лінійними методами.

# %% [markdown]
# За графіками видно, що деякі ознаки схожі між собою. Тому давайте також порахуємо кореляції між речовими ознаками.

# %% [markdown]
# ## Завдання 3
#
# Порахуйте попарні кореляції між ознаками temp, atemp, hum, windspeed(mph), windspeed(ms) і cnt
# за допомогою методу corr:

# %%
# find correlation between 'temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)', 'cnt'
some_features = ['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)', 'cnt']
correlations = df[some_features].corr()
print(correlations)
# Out:
#                     temp     atemp       hum  windspeed(mph)  windspeed(ms)  \
# temp            1.000000  0.991702  0.126963       -0.157944      -0.157944
# atemp           0.991702  1.000000  0.139988       -0.183643      -0.183643
# hum             0.126963  0.139988  1.000000       -0.248489      -0.248489
# windspeed(mph) -0.157944 -0.183643 -0.248489        1.000000       1.000000
# windspeed(ms)  -0.157944 -0.183643 -0.248489        1.000000       1.000000
# cnt             0.627494  0.631066 -0.100659       -0.234545      -0.234545
#
#                      cnt
# temp            0.627494
# atemp           0.631066
# hum            -0.100659
# windspeed(mph) -0.234545
# windspeed(ms)  -0.234545
# cnt             1.000000

# %% [markdown]
# На діагоналях, як і належить, стоять одиниці. Однак у матриці є ще дві пари сильно корелюючих стовпців: temp і atemp (корелюють за своєю природою) і два windspeed (тому що це просто переведення одних одиниць в інші). Далі ми побачимо, що цей факт негативно позначається на навчанні лінійної моделі.

# %% [markdown]
# Насамкінець подивимося середні ознак (метод mean), щоб оцінити масштаб ознак і частки 1 у бінарних ознак.

# %% [markdown]
# ## Завдання 4
#
# Виведіть середні ознак.

# %%
# Find the mean of the attribute
df.mean()
# Out:
# season               2.496580
# yr                   0.500684
# mnth                 6.519836
# holiday              0.028728
# weekday              2.997264
# workingday           0.683995
# weathersit           1.395349
# temp                20.310776
# atemp               23.717699
# hum                 62.789406
# windspeed(mph)      12.762576
# windspeed(ms)        5.705220
# cnt               4504.348837
# dtype: float64

# %% [markdown]
# Ознаки мають різний масштаб, отже, для подальшої роботи нам краще нормувати матрицю об'єкти-ознаки.

# %% [markdown]
# ### Проблема перша: колінеарні ознаки

# %% [markdown]
# Отже, у наших даних одна ознака дублює іншу, і є ще дві дуже схожі. Звичайно, ми могли б одразу видалити дублікати, але давайте подивимося, як відбувалося б навчання моделі, якби ми не помітили цю проблему.
#
# Для початку проведемо масштабування, або стандартизацію ознак: з кожної ознаки віднімемо її середнє і поділимо на стандартне відхилення. Це можна зробити за допомогою методу scale.
#
# Крім того, необхідно перемішати вибірку, це буде потрібно для крос-валідації.

# %%
from sklearn.preprocessing import scale
from sklearn.utils import shuffle

# %%
df_shuffled = shuffle(df, random_state=42)
X = scale(df_shuffled[df_shuffled.columns[:-1]])
y = df_shuffled["cnt"]

print("X: ", X)
print("y: ", y)
# Out:
# X:  [[ 1.354375    0.99863295  1.58866019 ...  0.74372737 -0.21121111
#   -0.21121111]
#  [-1.34821315 -1.00136893 -1.31026791 ... -1.33538868  1.12681211
#    1.12681211]
#  [ 1.354375   -1.00136893  1.00887457 ... -0.29551449  0.50349108
#    0.50349108]
#  ...
#  [ 1.354375   -1.00136893  0.71898176 ...  1.55169951 -0.5404777
#   -0.5404777 ]
#  [-1.34821315  0.99863295 -1.0203751  ... -1.06046036  0.41449871
#    0.41449871]
#  [-0.44735043 -1.00136893 -0.73048229 ...  1.34385394  0.77643372
#    0.77643372]]
# y:  703    6606
# 33     1550
# 300    3747
# 456    6041
# 633    7538
#        ...
# 71     2417
# 106    3744
# 270    3907
# 435    4911
# 102    2162
# Name: cnt, Length: 731, dtype: int64

# %% [markdown]
# Давайте навчимо лінійну регресію на наших даних і подивимося на ваги ознак.

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Завдання 5
#
# Створіть об'єкт лінійного регресора, навчіть його на всіх даних і виведіть ваги моделі (ваги зберігаються у змінній `coef_` класу регресора). Можна виводити пари (назва ознаки, вага), скориставшись функцією `zip`, вбудованою в мову python. Назви ознак зберігаються у змінній `df.columns`.

# %%
# find weigth
regressor = LinearRegression()
regressor.fit(X, y)

for feature , value in zip(df.columns, regressor.coef_):
    print(f'{feature}: {value}')
# Out:
# season: 570.8698404201848
# yr: 1021.9666808385737
# mnth: -141.30637067066573
# holiday: -86.76062843476119
# weekday: 137.22937294082004
# workingday: 56.39076518684175
# weathersit: -330.2330445706409
# temp: 367.4651342506935
# atemp: 585.5644765605813
# hum: -145.60373463359957
# windspeed(mph): 12460406274500.416
# windspeed(ms): -12460406274698.867

# %%
# Represents the intercept (also known as bias term) of the fitted model
regressor.intercept_
# Out:
# 4504.354529707314

# %% [markdown]
# Ми бачимо, що ваги при лінійно-залежних ознаках за модулем значно більші, ніж при інших ознаках. Щоб зрозуміти, чому так сталося, згадаємо аналітичну формулу, за якою обчислюються ваги лінійної моделі в методі найменших квадратів:
#
# $$w = (X^TX)^{-1} X^T y$$
#
# Якщо в $X$ є колінеарні (лінійно-залежні) стовпці, матриця $X^TX$ стає виродженою, і формула перестає бути коректною. Чим більш залежні ознаки, тим менший визначник цієї матриці й тим гірша апроксимація $Xw \approx y$. Таку ситуацію називають _проблемою мультиколінеарності_.

# %% [markdown]
# З парою (temp, atemp) трохи менше корелюючих змінних такого не сталося, однак на практиці завжди варто уважно стежити за коефіцієнтами при схожих ознаках.

# %% [markdown]
# Для того щоб розв'язати проблему мультиколінеарності, потрібно скористатися регуляризатором. До оптимізуючого функціоналу додають $L_1$ або $L_2$ норму ваг, помножену на коефіцієнт регуляризації $\alpha$. У першому випадку метод називається Lasso, а у другому — Ridge.

# %% [markdown]
# ### Завдання 6
# Давайте спробуємо навчити лінійні моделі з $L_1$ і $L_2$-регуляризацією, а далі порівняємо їхні ваги. Навчіть регресори Ridge і Lasso з параметрами за замовчуванням і переконайтеся, що проблема з вагами вирішилась.

# %% [markdown]
# Навчіть лінійну модель з $L_1$-регуляризацією (клас Lasso) і виведіть ваги.

# %%
from sklearn.linear_model import Lasso, Ridge

# %%
# Studying with Lasso
model_lasso = Lasso()
model_lasso.fit(X,y)
# Out:
# Lasso()

# %%
# Find the weights (using Lasso)
for feature , value in zip(df.columns, model_lasso.coef_):
    print(f'{feature}: {value}')
# Out:
# season: 560.2416160308865
# yr: 1019.4634940657198
# mnth: -128.73062703678733
# holiday: -86.15278133371098
# weekday: 137.347893904963
# workingday: 55.212370641356785
# weathersit: -332.3698569623486
# temp: 376.36323620969347
# atemp: 576.5307935045563
# hum: -144.12915500348578
# windspeed(mph): -197.13968940248455
# windspeed(ms): -2.805103823944435e-08

# %%
# Represents the intercept (also known as bias term) of the fitted model
model_lasso.intercept_
# Out:
# 4504.3488372093025

# %% [markdown]
# Навчіть лінійну модель з $L_2$-регуляризацією (клас Ridge) і виведіть ваги.

# %%
# Studying with Ridge
model_ridge = Ridge()
model_ridge.fit(X,y)
# Out:
# Ridge()

# %%
# Find the weights (using Ridge)
for feature, value in zip(df.columns, model_ridge.coef_):
    print(f'{feature}: {value}')
# Out:
# season: 563.0645722520163
# yr: 1018.948378787527
# mnth: -131.87332028247576
# holiday: -86.74609799709245
# weekday: 138.0051111787192
# workingday: 55.90311037506427
# weathersit: -332.3497884990726
# temp: 386.45788919191114
# atemp: 566.3470470600643
# hum: -145.07132729867305
# windspeed(mph): -99.25944108182756
# windspeed(ms): -99.25944115430536

# %%
# Represents the intercept (also known as bias term) of the fitted model
model_ridge.intercept_
# Out:
# 4504.3488372093025

# %% [markdown]
# ### Завдання 7
#
# На відміну від $L_2$-регуляризації, $L_1$ обнуляє ваги при деяких ознаках. Давайте поспостерігаємо, як змінюються ваги зі збільшенням коефіцієнта регуляризації $\alpha$.

# %% [markdown]
# Для кожного значення коефіцієнта з `alphas` навчіть регресор `Lasso` і запишіть ваги у список `coefs_lasso`, а потім навчіть `Ridge` і запишіть ваги у список`coefs_ridge`. Конвертуйте отримані списки в `np.array`.

# %%
alphas = np.arange(1, 500, 50)

coefs_lasso = []
coefs_ridge = []

for alpha in alphas:
    model_lasso.set_params(alpha=alpha)
    model_lasso.fit(X,y)
    coefs_lasso.append(model_lasso.coef_)
    
    model_ridge.set_params(alpha=alpha)
    model_ridge.fit(X,y)
    coefs_ridge.append(model_ridge.coef_)
    
coefs_lasso = np.array(coefs_lasso)
coefs_ridge = np.array(coefs_ridge)
    
print("Coef Lasso: ", coefs_lasso)
print("Coef Ridge: ", coefs_ridge)
# Out:
# Coef Lasso:  [[ 5.60241616e+02  1.01946349e+03 -1.28730627e+02 -8.61527813e+01
#    1.37347894e+02  5.52123706e+01 -3.32369857e+02  3.76363236e+02
#    5.76530794e+02 -1.44129155e+02 -1.97139689e+02 -2.80510382e-08]
#  [ 4.10969632e+02  9.77019409e+02 -0.00000000e+00 -5.34489688e+01
#    9.19434374e+01  1.75372118e+01 -3.18125568e+02  3.22829934e+02
#    6.10031512e+02 -9.10689615e+01 -1.45066095e+02 -2.29895576e-08]
#  [ 3.70077089e+02  9.35945490e+02  0.00000000e+00 -1.21619360e+01
#    4.88886342e+01  0.00000000e+00 -3.08805664e+02  2.69417263e+02
#    6.32502623e+02 -2.75042876e+01 -9.37749037e+01 -2.41636842e-08]
#  [ 3.32835717e+02  8.91870058e+02  0.00000000e+00 -0.00000000e+00
#    0.00000000e+00  0.00000000e+00 -2.79616688e+02  2.11052030e+02
#    6.62920880e+02 -0.00000000e+00 -5.01551472e+01 -2.62778724e-08]
#  [ 2.98134448e+02  8.45652857e+02  0.00000000e+00 -0.00000000e+00
#    0.00000000e+00  0.00000000e+00 -2.35571345e+02  1.24144807e+02
#    7.25379483e+02 -0.00000000e+00 -1.26461769e+01 -2.78799567e-08]
#  [ 2.58927201e+02  7.99237273e+02  0.00000000e+00 -0.00000000e+00
#    0.00000000e+00  0.00000000e+00 -1.90821549e+02  7.20759379e+01
#    7.50363107e+02 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00]
#  [ 2.17427513e+02  7.52720808e+02  0.00000000e+00 -0.00000000e+00
#    0.00000000e+00  0.00000000e+00 -1.45713398e+02  3.77153655e+01
#    7.56296866e+02 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00]
#  [ 1.75929845e+02  7.06203788e+02  0.00000000e+00 -0.00000000e+00
#    0.00000000e+00  0.00000000e+00 -1.00605389e+02  3.66093817e+00
#    7.61926337e+02 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00]
#  [ 1.34628497e+02  6.59632535e+02  0.00000000e+00 -0.00000000e+00
#    0.00000000e+00  0.00000000e+00 -5.55110633e+01  0.00000000e+00
#    7.37348061e+02 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00]
#  [ 9.33517423e+01  6.13054639e+02  0.00000000e+00 -0.00000000e+00
#    0.00000000e+00  0.00000000e+00 -1.04185690e+01  0.00000000e+00
#    7.09130877e+02 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00]]
# Coef Ridge:  [[ 563.06457225 1018.94837879 -131.87332028  -86.746098    138.00511118
#     55.90311038 -332.3497885   386.45788919  566.34704706 -145.0713273
#    -99.25944108  -99.25944115]
#  [ 461.1786324   954.30774189  -41.56545001  -84.91347027  126.60366663
#     54.2516911  -313.27515141  458.90147709  481.44350031 -151.29101033
#   -101.62731482 -101.62731483]
#  [ 403.97653045  898.08362212    5.67424346  -81.91106159  117.94141144
#     52.72848389 -298.40898086  455.28986839  467.43141748 -152.68605059
#   -102.10167084 -102.10167084]
#  [ 366.60423851  848.46346471   34.02728278  -78.77196479  110.68012006
#     51.25719208 -286.12515935  447.47982533  455.75402966 -151.48320603
#   -102.00537592 -102.00537593]
#  [ 339.74528956  804.25104797   52.48987295  -75.71740756  104.40346414
#     49.84189502 -275.48609488  438.50968939  444.7642744  -148.94396978
#   -101.58638458 -101.58638458]
#  [ 319.15864133  764.5614337    65.15200737  -72.81970821   98.87880449
#     48.4845255  -266.00255564  429.21412336  434.23523472 -145.6981149
#   -100.96471143 -100.96471143]
#  [ 302.63606049  728.70854018   74.13828141  -70.09898324   93.95581101
#     47.18533838 -257.390629    419.9261517   424.12192175 -142.08934531
#   -100.20862041 -100.20862041]
#  [ 288.91327631  696.14581646   80.660457    -67.55485237   89.52867543
#     45.94346702 -249.47139541  410.80018411  414.40937279 -138.31653824
#    -99.36066117  -99.36066117]
#  [ 277.21321566  666.42974721   85.45925409  -65.17870596   85.51866655
#     44.75730348 -242.12439914  401.91194457  405.08585263 -134.4990383
#    -98.44906427  -98.44906427]
#  [ 267.03109023  639.19536755   89.01232285  -62.95890597   81.86490933
#     43.62477037 -235.26399722  393.29798599  396.13815546 -130.70987223
#    -97.49343362  -97.49343362]]

# %% [markdown]
# Проаналізуйте динаміку ваг при збільшенні параметра регуляризації:

# %%
plt.figure(figsize=(8, 5))

for coef, feature in zip(coefs_lasso.T, df.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3))

plt.legend(loc="upper right", bbox_to_anchor=(1.4, 0.95))
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Lasso")

plt.figure(figsize=(8, 5))
for coef, feature in zip(coefs_ridge.T, df.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3))

plt.legend(loc="upper right", bbox_to_anchor=(1.4, 0.95))
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Ridge")

plt.show()

# %% [markdown]
# Проаналізуйте графіки та дайте відповіді на такі запитання.
#
# 1. Який регуляризатор (Ridge або Lasso) агресивніше зменшує ваги при одному й тому самому alpha?
# > Відповідь: Lasso
# 1. Що станеться з вагами Lasso, якщо alpha зробити дуже великим? Поясніть, чому так відбувається.
# > Відповідь: При збільшені alpha ваги Lasso наближаються до 0. Данне явище відюувається через так звану регуляцію. При дуже великих значеннях alpha функція штрафу за великі значення коефіцієнтів стає набагато більшою, ніж втрати функції втрати (наприклад, середньоквадратична помилка). Це призводить до того, що модель старається знайти найменшу кількість впливових ознак, або навіть ігнорує їх зовсім, щоб зменшити загальну штрафну функцію. Данну закономірність можемо побачити на графіку.
# 1. Чи можна стверджувати, що `Lasso` виключає одну з ознак `windspeed` при будь-якому значенні `alpha > 0`? А Ridge? Вважається, що регуляризатор виключає ознаку, якщо коефіцієнт при ньому менший $10^{-3}$.
# > Відповідь: так, можна стверджувати, що модель Lasso виключить одну з ознак windspeed при будь-якому значенні alpha > 0. Оскільки Lasso використовує L1-регуляризацію, яка включає штраф за суму абсолютних значень коефіцієнтів. Отже, деякі коефіцієнти можуть бути зменшені до нуля, що ефективно виключає відповідні ознаки з моделі. Ні, не можна стверджувати, що модель Ridge виключить одну з ознак windspeed. Оскільки модель Ridge використовує L2-регуляризацію, яка включає штраф за квадрат суми коефіцієнтів. Данний тип регуляризації має тенденцію зменшувати значення коефіцієнтів, але не призводить до виключення ознак з моделі тобто прирівнювання до нуля.
# 1. Який із регуляризаторів підійде для відбору неінформативних ознак?
# > Відповідь: Lasso, бо використовує L1-регуляризацію і може зменьшувати деякі коефіцієнти до 0.

# %% [markdown]
# ### Завдання 8
#
# Далі будемо працювати з `Lasso`.
#
# Отже, ми бачимо, що при зміні alpha модель по-різному підбирає коефіцієнти ознак. Нам потрібно вибрати найкраще alpha.
#
# Для цього, по-перше, нам потрібна метрика якості. Будемо використовувати як метрику сам оптимізований функціонал методу найменших квадратів, тобто `Mean Square Error`.
#
# По-друге, потрібно зрозуміти, на яких даних цю метрику рахувати. Не можна вибирати `alpha` за значенням MSE на навчальній вибірці, тому що тоді ми не зможемо оцінити, як модель буде робити передбачення на нових для неї даних. Якщо ми виберемо одне розбиття вибірки на навчальну та тестову (це називається holdout), то налаштуємося на конкретні "нові" дані, і знову можемо перенавчитися. Тому будемо робити декілька розбиттів вибірки, на кожному пробувати різні значення alpha, а потім усереднювати MSE. Найзручніше робити такі розбиття крос-валідацією, тобто розділити вибірку на $K$ частин, і кожного разу брати одну з них як тестову, а з блоків, що залишилися, складати навчальну вибірку.

# %% [markdown]
# Робити крос-валідацію для регресії в sklearn зовсім просто: для цього є спеціальний регресор, __LassoCV__, який бере на вхід список із alpha і для кожного з них обчислює MSE на крос-валідації. Після навчання (якщо залишити параметр cv=3 за замовчуванням) регресор буде містити змінну __mse\_path\___, матрицю розміру len(alpha) x k, k = 3 (число блоків у крос-валідації), що містить значення MSE на тесті для відповідних запусків. Крім того, у змінній alpha\_ буде зберігатися вибране значення параметра регуляризації, а в coef\_, традиційно, навчені ваги, що відповідають цьому alpha_.
#
# Зверніть увагу, що регресор може змінювати порядок, у якому він проходить по alphas; для зіставлення з матрицею MSE краще використовувати змінну регресора alphas_.

# %% [markdown]
# Навчіть регресор `LassoCV` на всіх параметрах регуляризації з alpha. Побудуйте графік _усередненого_ за рядками `MSE` в залежності від `alpha` (використовуйте для цього функцію `create_plot`).
#
# Виведіть вибране `alpha`, а також пари "ознака-коефіцієнт" для навченого вектора коефіцієнтів.

# %%
def create_plot(data, title, xlabel, ylabel, figsize=None, min=None):
    size = figsize or (15, 5)
    plt.figure(figsize=size)

    x = list(map(lambda e: e[0], data))
    y = list(map(lambda e: e[1], data))
    plt.plot(x, y, marker='o', linestyle='-', color='b')
    if min is not None:
      plt.text(min[0], min[1], f"min: {int(min[0])}x{int(min[1])}", ha="center")
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    plt.grid()
    plt.show()

# %%
# find the best alpha
from sklearn.linear_model import LassoCV

alphas = np.arange(1, 100, 5)

regressor_lasso = LassoCV(alphas=alphas, cv=3)
regressor_lasso.fit(X, y)

selected_alpha = regressor_lasso.alpha_
print("Selected alpha:", selected_alpha)

mse_values = np.mean(regressor_lasso.mse_path_, axis=1)
data = list(zip(regressor_lasso.alphas_, mse_values))
print(data)
title = "MSE vs. Alpha for Lasso"
create_plot(data, title, xlabel='Lambda', ylabel='MSE')
# Out:
# Selected alpha: 6
# [(96, 851990.7226862232), (91, 846392.1588364622), (86, 840822.7945299605), (81, 835574.3424234892), (76, 830286.6292664969), (71, 825198.4820010142), (66, 820159.7018859917), (61, 815491.2384371455), (56, 811192.9043818455), (51, 807264.7026273537), (46, 803575.5866471971), (41, 800211.2474620757), (36, 797217.5699930107), (31, 794594.560667227), (26, 792342.1957655508), (21, 789464.6632025442), (16, 786750.8408386442), (11, 783634.3772912041), (6, 781531.0908199241), (1, 785055.1467870097)]

# %% [markdown]
# Отже, ми вибрали певний параметр регуляризації. Давайте подивимося, які б ми вибирали alpha, якби ділили вибірку лише один раз на навчальну та тестову, тобто розглянемо траєкторії MSE, що відповідають окремим блокам вибірки.

# %% [markdown]
# ### Завдання 9
#
# Виведіть значення `alpha`, що відповідають мінімумам `MSE` на кожному розбитті (тобто за стовпцями).
# На трьох окремих графіках візуалізуйте стовпці `mse_path_`.

# %%
print(regressor_lasso.mse_path_.shape)
# Out:
# (20, 3)

# %%
min_values = np.min(regressor_lasso.mse_path_, axis=0)
print(f"{min_values=}")
min_idx = np.argmin(regressor_lasso.mse_path_, axis=0)
print(f"{min_idx=}")

def create_alphas_diagram(data, title, xlabel, ylabel, min):
    size = (15, 5)
    plt.figure(figsize=size)

    x = data[0]
    y = data[1]
    plt.plot(x, y, marker='o', linestyle='-', color='purple')

    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    if min is not None:
      plt.text(min[0], min[1], f"min: {int(min[0])}x{int(min[1])}", ha="center")

    plt.grid()
    plt.show()

name = "Depends MSE on alhpa"
for col in range(regressor_lasso.mse_path_.shape[1]):
  data = np.vstack((regressor_lasso.alphas_, regressor_lasso.mse_path_[:,col]))
  create_alphas_diagram(data,f"{name} {col+1}","Alpha","MSE",min=(alphas[col], min_values[col]))
# Out:
# min_values=array([733725.76040522, 799433.16736917, 796979.89551936])
# min_idx=array([18, 19,  9])

# %% [markdown]
# На кожному розбитті оптимальне значення `alpha` своє, і йому відповідає велике MSE на інших розбиттях. Виходить, що ми налаштовуємося на конкретні навчальні та контрольні вибірки. При виборі `alpha` на крос-валідації ми вибираємо дещо "середнє", що даватиме прийнятне значення метрики на різних розбиттях вибірки.

# %% [markdown]
# ### Завдання 10
#
# Нарешті, як прийнято в аналізі даних, давайте проінтерпретуємо результат. Дайте відповіді на наступні запитання.

# %% [markdown]
# #### Запитання 1
#
# В останній навченій моделі виберіть 4 ознаки з найбільшими (позитивними) коефіцієнтами (і випишіть їх), подивіться на візуалізації залежностей `cnt` від цих ознак, які ми зображали у блоці "Ознайомлення з даними". Чи видно зростаючу лінійну залежність `cnt` від цих ознак за графіками? Чи логічно стверджувати (виходячи зі здорового глузду), що чим більше значення цих ознак, тим більше людей захочуть взяти велосипеди?

# %% [markdown]
# __Відповідь:__

# %%
print(f"{regressor_lasso.coef_.shape=}")
for f,w in zip(df.columns, regressor_lasso.coef_):
  print(f"{f:15}: {w.round(4)}")
# Out:
# regressor_lasso.coef_.shape=(12,)
# season         : 532.019
# yr             : 1015.0602
# mnth           : -100.0395
# holiday        : -83.294
# weekday        : 132.5045
# workingday     : 51.5571
# weathersit     : -330.5599
# temp           : 370.6799
# atemp          : 581.3969
# hum            : -140.0074
# windspeed(mph) : -191.7714
# windspeed(ms)  : -0.0

# %% [markdown]
# > 1) yr 1015.06 ні не можно сказати , що наявна залежність, бо не обовязково при збільшені року буде збільшуватися число прокатів.
# > 2) atemp 581.39 - можливо припустити, що погода має сплив на кількість оренд.
# > 3) season 532.019 - помітна закономірність, що сезон має сплив на кількість оренд.
# > 4) temp 370 - наявна закономірність, що температура має сплив на кількість оренд.

# %% [markdown]
# #### Запитання 2
#
# Виберіть 3 ознаки з найбільшими за модулем негативними коефіцієнтами (і випишіть їх), подивіться на відповідні візуалізації. Чи видно лінійну залежність, що зменшується? Чи логічно стверджувати, що чим більша величина цих ознак, тим менше людей захочуть взяти велосипеди?

# %% [markdown]
# __Відповідь:__

# %% [markdown]
# > 1) weathersit: -330.5599 Лінійну залежність наявна та можно стверджувати , що при збільшенні ознаки кількість оренд зменьшиться
# > 2) windspeed(mph): -191.7714 Лінійну залежність наявна та можно стверджувати , що при збільшенні ознаки кількість оренд зменьшиться
# > 3) hum: -140.0074 Лінійну залежність наявна та можно стверджувати , що при збільшенні ознаки кількість оренд зменьшиться

# %% [markdown]
# #### Запитання 3
#
# Випишіть ознаки з коефіцієнтами, близькими до нуля (< 1e-3). Як ви думаєте, чому модель виключила їх із моделі (знову подивіться на графіки)? Чи правда, що вони ніяк не впливають на попит на велосипеди?

# %% [markdown]
# __Відповідь:__

# %%
data_coef = pd.DataFrame(regressor_lasso.coef_,index=df.columns[:-1], columns=["Weight"])
data_coef
# Out:
#                       Weight
# season          5.320190e+02
# yr              1.015060e+03
# mnth           -1.000395e+02
# holiday        -8.329396e+01
# weekday         1.325045e+02
# workingday      5.155709e+01
# weathersit     -3.305599e+02
# temp            3.706799e+02
# atemp           5.813969e+02
# hum            -1.400074e+02
# windspeed(mph) -1.917714e+02
# windspeed(ms)  -2.685698e-08

# %%
data_coef[data_coef.abs() < 1e-03].dropna()
# Out:
#                      Weight
# windspeed(ms) -2.685698e-08

# %% [markdown]
# > windspeed(ms): -2.685698e-08 Дана ознака слабо впливає на цільову змінну (кількість арендованих велосипедів), що є причиною незначної кореляції. Тому при регуляції Lasso ця характеристика була наближена (прирівнена) до 0.

# %% [markdown]
# ### Висновок
# Отже, ми подивилися, як можна стежити за адекватністю лінійної моделі, як відбирати ознаки і як грамотно, за можливості не налаштовуючись на якусь конкретну порцію даних, підбирати коефіцієнт регуляризації.
#
# Варто зазначити, що за допомогою крос-валідації зручно підбирати лише невелику кількість параметрів. (1, 2, максимум 3), тому що для кожної допустимої їх комбінації нам доводиться декілька разів навчати модель. Такий процес займає багато часу, особливо якщо треба навчатися на великих обсягах даних.
